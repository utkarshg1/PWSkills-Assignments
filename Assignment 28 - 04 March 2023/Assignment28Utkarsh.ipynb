# %% [markdown]
# <a id="0"></a>
#
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Assignment  28: Plotly - Utkarsh Gaikwad</p>

# %% [markdown]
# [Assignment pdf link](04%20Mar_AssQ_Plotly.pdf)

# %% [markdown]
# <a id="nbviewer"></a>
#
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Notebook PDF output</p>

# %% [markdown]
# ### Please note that GitHub does not render the Plotly graphs

# %% [markdown]
# ### Notebook PDF output : [Assignment28Utkarsh.pdf](./Outputs/Assignment28Utkarsh.pdf)

# %% [markdown]
# ### HTML Page output : [Assignment28Utkarsh.html](./Outputs/Assignment28Utkarsh.html)

# %% [markdown]
# ### Please note that You need to download and run this notebook to view the plotly graphs as it is dynamic

# %% [markdown]
# <a id="1"></a>
#
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 1</p>

# %% [markdown]
# ## Question 1: Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a scatter plot for age and fare columns in the titanic dataset.
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### Loading titanic dataset

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Plotting the scatter plot

# %%
import plotly.express as px
# Plot a scatter plot for "age" and "fare" columns using Plotly express
fig = px.scatter(titanic, 
                 x="age",
                 y="fare", 
                 title="Titanic Dataset: Age vs. Fare")

# Update the layout to center the title above the plot
fig.update_layout(
    title={
        'text': "Titanic Dataset: Age vs. Fare",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show()

# %% [markdown]
# ### Screenshot of Question 1 Output (shown because of GitHub not rendering rich formats)

# %% [markdown]
# ![Question 1 Output](./Screenshots/Question1.jpg)

# %% [markdown]
# <a id="2"></a>
#
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 2</p>

# %% [markdown]
# ## Question 2: Using the tips dataset in the Plotly library, plot a box plot using Plotly express
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### Importing tips dataset from plotly express

# %%
import plotly.express as px
tips = px.data.tips()
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Plotting Boxplot

# %%
# Plot a box plot for the "total_bill" column using Plotly express
fig = px.box(tips,x='day',y="total_bill", title="Tips Dataset: Total Bill Box Plot")
fig.show()

# %% [markdown]
# ### Screenshot of Question 2 Output (shown because of GitHub not rendering rich formats)

# %% [markdown]
# ![Question 2 Output](./Screenshots/Question2.jpg)

# %% [markdown]
# <a id="3"></a>
#
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 3</p>

# %% [markdown]
# ## Question 3: Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day"column with the color parameter.
# ---

# %% [markdown]
# ## Answer:

# %%
# Plot a histogram for "sex" and "total_bill" columns using Plotly express
fig = px.histogram(tips, x="sex", y="total_bill", 
                   color="day", pattern_shape="smoker",
                   title="Tips Dataset: Total Bill by Gender and Smoking Status")

fig.show()

# %% [markdown]
# ### Screenshot of Question 3 Output (shown because of GitHub not rendering rich formats)

# %% [markdown]
# ![Question 3 Output](./Screenshots/Question3.jpg)

# %% [markdown]
# <a id="4"></a>
#
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 4</p>

# %% [markdown]
# ## Question 4: Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for the color parameter.
# ### Note : Use "sepal_length", "sepal_width", "petal_length", "petal_width" columns only with the dimensions parameter.
# ---

# %% [markdown]
# ## Answer :

# %%
import plotly.express as px

# Load the "iris" dataset from Plotly
iris = px.data.iris()

# Plot a scatter matrix plot using Plotly express
fig = px.scatter_matrix(iris, 
                        dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"],
                        color="species", title="Iris Dataset: Scatter Matrix Plot")

# Updating the height of figure
fig.update_layout(height=800)

fig.show()

# %% [markdown]
# ### Screenshot of Question 4 Output (shown because of GitHub not rendering rich formats)

# %% [markdown]
# ![Question 4 Output](./Screenshots/Question4.jpg)

# %% [markdown]
# <a id="5"></a>
#
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 5</p>

# %% [markdown]
# ## Question 5: What is Distplot? Using Plotly express, plot a distplot
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### A Distplot or distribution plot, depicts the variation in the data distribution. Seaborn Distplot represents the overall distribution of continuous data variables.
#
# ### The Seaborn module along with the Matplotlib module is used to depict the distplot with different variations in it. The Distplot depicts the data by a histogram and a line in combination to it.
#
# ### Plotly express has px.histogram as the function

# %%
import plotly.express as px
tips = px.data.tips()
fig = px.histogram(tips, x="total_bill", y="tip", color="sex",
                   marginal="box", # or violin, rug
                   hover_data=tips.columns)
fig.show()

# %% [markdown]
# ### Screenshot of Question 5 above Output (shown because of GitHub not rendering rich formats)

# %% [markdown]
# ![Question 5a](./Screenshots/Question5a.jpg)

# %% [markdown]
# ### Can also plot distplot like below

# %%
import plotly.figure_factory as ff
import numpy as np
np.random.seed(2)

x = np.random.randn(1000)
hist_data = [x]
group_labels = ['distplot'] # name of the dataset

fig = ff.create_distplot(hist_data, group_labels)
fig.show()

# %% [markdown]
# ### Screenshot of Question 5 above Output (shown because of GitHub not rendering rich formats)

# %% [markdown]
# ![Question 5b](./Screenshots/Question5b.jpg)
