# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Assignment  84: Anomaly Detection 2 - Utkarsh Gaikwad</p>

# %% [markdown]
# [Assignment pdf link](./03%20May_AssQ.pdf)

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 1</p>

# %% [markdown]
# ## Question 1: What is the role of feature selection in anomaly detection?
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### Feature selection plays a crucial role in anomaly detection as it helps to identify the most relevant and informative features or variables that can help distinguish normal behavior from anomalous behavior. Anomaly detection is the process of identifying patterns or instances in data that deviate significantly from what is considered to be normal or expected.
#
# ### The selection of features is important in anomaly detection because it directly affects the performance of the detection algorithm. If irrelevant or redundant features are included, the algorithm may be less effective at detecting anomalies, as these features can introduce noise and reduce the signal-to-noise ratio. On the other hand, if important features are left out, the algorithm may miss important information and also lead to less accurate results.
#
# ### In feature selection, a subset of the original set of features is selected based on certain criteria, such as relevance, redundancy, and correlation. Various techniques such as correlation analysis, mutual information, principal component analysis (PCA), and others can be used to perform feature selection. By selecting the most relevant and informative features, anomaly detection algorithms can better distinguish normal behavior from anomalous behavior and produce more accurate results.
#
# ### Therefore, feature selection is an important step in the process of anomaly detection, and it can greatly affect the performance and accuracy of the detection algorithm.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 2</p>

# %% [markdown]
# ## Question 2: What are some common evaluation metrics for anomaly detection algorithms and how are they computed?
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### There are several common evaluation metrics for anomaly detection algorithms, some of which are:
#
# 1. `True Positive Rate (TPR) or Recall`: This metric measures the proportion of actual anomalies that are correctly identified by the algorithm. It is computed as TPR = TP / (TP + FN), where TP is the number of true positives (anomalies correctly identified), and FN is the number of false negatives (anomalies missed by the algorithm).
#
# 2. `False Positive Rate (FPR)`: This metric measures the proportion of normal instances that are incorrectly classified as anomalies by the algorithm. It is computed as FPR = FP / (FP + TN), where FP is the number of false positives (normal instances incorrectly identified as anomalies), and TN is the number of true negatives (normal instances correctly identified).
#
# 3. `Precision`: This metric measures the proportion of instances that are truly anomalous among all instances identified as anomalies by the algorithm. It is computed as Precision = TP / (TP + FP).
#
# 4. `F1 Score`: This metric is the harmonic mean of Precision and Recall and provides a single score that balances both metrics. It is computed as F1 Score = 2 * Precision * Recall / (Precision + Recall).
#
# 5. `Receiver Operating Characteristic (ROC) Curve`: This metric visualizes the trade-off between TPR and FPR at different threshold values. The ROC curve plots TPR against FPR for different threshold values, and the area under the curve (AUC) is a common metric to compare the performance of different algorithms. A higher AUC indicates better performance.
#
# ### These evaluation metrics can be computed using the confusion matrix, which is a table that summarizes the number of true positives, false positives, true negatives, and false negatives. The confusion matrix can be constructed by comparing the actual labels with the predicted labels generated by the anomaly detection algorithm.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 3</p>

# %% [markdown]
# ## Question 3 : What is DBSCAN and how does it work for clustering?
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### DBSCAN (Density-Based Spatial Clustering of Applications with Noise) is a popular clustering algorithm that can identify clusters of arbitrary shape in a dataset, as well as detect outliers as noise. It was first introduced by Martin Ester, Hans-Peter Kriegel, Jörg Sander, and Xiaowei Xu in 1996.
#
# ### The main idea behind DBSCAN is to group together data points that are closely packed together, while considering the density of the points within the neighborhood. It defines clusters as dense regions of points that are separated by regions of lower density, and outliers as points that lie in regions of low density.
#
# ### To perform clustering with DBSCAN, the algorithm requires two parameters: epsilon (ε) and minimum number of points (minPts). Epsilon defines the radius of a neighborhood around a data point, and minPts defines the minimum number of data points required to form a dense region. The algorithm works as follows:
#
# 1. Randomly select an unvisited data point.
#
# 2. If the number of data points within the ε-neighborhood of the point is greater than or equal to minPts, mark the point as a core point and create a new cluster.
#
# 3. Expand the cluster by recursively adding all directly reachable data points that are within the ε-neighborhood of the core point.
#
# 4. Continue this process until the cluster is complete, i.e., no more points can be added to it.
#
# 5. Move to the next unvisited data point and repeat the above steps until all points have been visited.
#
# ### Any data point that is not a core point and does not have enough neighbors to form a cluster is considered an outlier or noise. The algorithm can be sensitive to the choice of the parameters ε and minPts, and finding the optimal values can be a challenging task.
#
# ### DBSCAN has several advantages over other clustering algorithms, such as its ability to handle clusters of arbitrary shape and its ability to identify noise as outliers. However, it may not work well on datasets with varying densities or datasets with high-dimensional features.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 4</p>

# %% [markdown]
# ## Question 4 : How does the epsilon parameter affect the performance of DBSCAN in detecting anomalies?
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### In DBSCAN, the epsilon (ε) parameter is a crucial parameter that affects the performance of the algorithm in detecting anomalies. It defines the radius of a neighborhood around a data point, and is used to determine whether a point is considered part of a dense region or not.
#
# ### The choice of the ε parameter can greatly affect the performance of DBSCAN in detecting anomalies. If the ε parameter is set too small, the algorithm may identify many small clusters and treat them as noise, resulting in a high false positive rate. On the other hand, if the ε parameter is set too large, the algorithm may group together too many points and treat them as normal, resulting in a high false negative rate.
#
# ### To detect anomalies using DBSCAN, one approach is to set a relatively large value for the ε parameter to ensure that only points that are far away from any cluster are considered as outliers or anomalies. This approach can help reduce the false positive rate, but may also increase the false negative rate if the anomalies are located within the clusters.
#
# ### Another approach is to use a range of values for the ε parameter and evaluate the performance of the algorithm on different values. This can be done using techniques such as the elbow method or silhouette score, which can help determine the optimal value for the ε parameter that maximizes the performance of the algorithm in detecting anomalies.
#
# ### In general, the choice of the ε parameter depends on the specific characteristics of the dataset and the type of anomalies being detected. It is important to carefully tune the ε parameter and evaluate its impact on the performance of the algorithm to achieve optimal results.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 5</p>

# %% [markdown]
# ## Question 5 : What are the differences between the core, border, and noise points in DBSCAN, and how do they relate to anomaly detection?
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### In DBSCAN, each data point is classified into one of three categories: core points, border points, and noise points. These categories are based on the density of points within their neighborhood and their distance to other clusters.
#
# 1. `Core points`: A core point is a data point that has at least minPts (a predefined parameter) other points within its ε-neighborhood. Core points are typically located at the center of a cluster and are important in defining the boundaries of the cluster. In anomaly detection, core points can be considered normal points or inliers.
#
# 2. `Border points`: A border point is a data point that is not a core point but has at least one core point within its ε-neighborhood. Border points are on the periphery of a cluster and are considered part of the cluster. In anomaly detection, border points can be considered normal points or inliers, but may have a lower degree of certainty compared to core points.
#
# 3. `Noise points`: A noise point is a data point that is neither a core point nor a border point. Noise points are typically located in low-density areas of the dataset and do not belong to any cluster. In anomaly detection, noise points can be considered anomalies or outliers.
#
# ### In general, core points and border points are considered to be part of normal patterns or clusters, while noise points are considered to be anomalous or outliers. However, the exact interpretation of these points can depend on the specific characteristics of the dataset and the application domain.
#
# ### DBSCAN can be used for anomaly detection by identifying the noise points or by considering points that are far from any cluster as anomalies. The ability of DBSCAN to identify anomalies is based on its ability to identify low-density areas in the dataset, which are typically indicative of anomalies or outliers. However, the performance of DBSCAN in detecting anomalies depends on the choice of its parameters, such as ε and minPts, as well as the specific characteristics of the dataset.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 6</p>

# %% [markdown]
# ## Question 6 : How does DBSCAN detect anomalies and what are the key parameters involved in the process?
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### DBSCAN (Density-Based Spatial Clustering of Applications with Noise) is a popular unsupervised clustering algorithm that can also be used for anomaly detection. The algorithm detects anomalies by identifying low-density areas in the dataset that are far from any cluster.
#
# ### The key idea behind DBSCAN is that clusters are dense regions of the dataset separated by regions of lower density. DBSCAN defines a neighborhood around each data point and groups together points that are close to each other and have high density. Points that are far from any dense region are considered outliers or anomalies.
#
# ### The algorithm has two main parameters that are critical for anomaly detection:
#
# 1. `Epsilon (ε)`: This parameter defines the radius of a neighborhood around each data point. Points within the ε-neighborhood of a point are considered neighbors. The ε parameter can be used to control the granularity of the clustering and the number of points considered as outliers.
#
# 2. `MinPts`: This parameter specifies the minimum number of points that must be present in the ε-neighborhood of a data point for it to be considered a core point. Points that have fewer than MinPts neighbors are considered border points or noise points. The MinPts parameter can be used to control the minimum density of a cluster and to filter out small clusters and noise points.
#
# ### To detect anomalies using DBSCAN, the algorithm is typically run with a large value of ε to identify points that are far from any cluster. The points that are not part of any cluster are considered anomalies or outliers. The choice of ε and MinPts can significantly impact the number of anomalies detected and the accuracy of the results. In practice, it is often necessary to experiment with different values of these parameters to find the optimal configuration for a specific dataset and application.
#
# ### Overall, DBSCAN can be a powerful tool for anomaly detection, especially in high-dimensional datasets or datasets with complex structures. However, like all clustering algorithms, it has limitations and may not work well in all situations. Careful evaluation and interpretation of the results are critical for successful anomaly detection with DBSCAN.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 7</p>

# %% [markdown]
# ## Question 7 : What is the make_circles package in scikit-learn used for?
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### The make_circles function is a part of the datasets module in the scikit-learn library, and it is used to generate a 2D toy dataset of data points arranged in the form of two interleaving circles.
#
# ### The make_circles function generates a dataset that can be used for testing and benchmarking clustering algorithms, especially those that are designed to handle non-linearly separable data. The dataset is often used to evaluate the performance of clustering algorithms, such as DBSCAN or Spectral Clustering, in separating the two circles and identifying their boundaries.
#
# ### The make_circles function takes several arguments that allow for control over the properties of the generated dataset, such as the number of samples, noise level, and scaling. It returns a tuple of two arrays: the input data array, which contains the coordinates of the data points in the 2D space, and the target labels, which indicate the cluster to which each point belongs.
#
# ### Overall, make_circles is a convenient tool for generating synthetic datasets for testing and evaluating clustering algorithms, especially those designed for non-linearly separable data.
#
# ### Below is example python code:

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles

# Generate a synthetic dataset with 500 samples, noise level of 0.05, and scaling of 0.8
X, y = make_circles(n_samples=500, noise=0.05, factor=0.8)

# Visualize the generated dataset
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.show()

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 8</p>

# %% [markdown]
# ## Question 8: What are local outliers and global outliers, and how do they differ from each other?
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### Local outliers and global outliers are two different types of anomalies that can occur in a dataset.
#
# ### A local outlier is an anomaly that is only anomalous with respect to its local neighborhood or context. In other words, a local outlier is a data point that is considered anomalous only when compared to the surrounding data points. For example, in a clustering algorithm such as DBSCAN, a local outlier is a point that is not part of any cluster and is located in a sparse or low-density area of the dataset. Local outliers are often detected using density-based techniques that rely on the concept of neighborhoods, such as DBSCAN or Local Outlier Factor (LOF).
#
# ### On the other hand, a global outlier is an anomaly that is anomalous with respect to the entire dataset. In other words, a global outlier is a data point that is considered anomalous when compared to all other data points in the dataset. For example, in a regression or classification problem, a global outlier is a data point that has an extremely large or small value for the target variable compared to all other data points in the dataset. Global outliers are often detected using statistical techniques that rely on the concept of distribution, such as z-scores, Tukey's fences, or Mahalanobis distance.
#
# ### In summary, local outliers are anomalies that are anomalous only in the context of their local neighborhood, whereas global outliers are anomalies that are anomalous with respect to the entire dataset. The detection of local outliers is often performed using density-based techniques, while the detection of global outliers is often performed using statistical techniques.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 9</p>

# %% [markdown]
# ## Question 9: How can local outliers be detected using the Local Outlier Factor (LOF) algorithm?
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### The Local Outlier Factor (LOF) algorithm is a popular density-based technique for detecting local outliers in a dataset. The LOF algorithm computes a score for each data point in the dataset based on its local density relative to the densities of its k-nearest neighbors. A data point with a significantly lower density than its neighbors is considered a potential local outlier.
#
# ### Here are the main steps involved in using the LOF algorithm to detect local outliers:
#
# 1. Determine the value of k, the number of nearest neighbors to consider when computing the local density. This parameter can be set based on the characteristics of the dataset and the desired level of sensitivity to local outliers.
#
# 2. Compute the distance between each data point and its k-nearest neighbors. This can be done using any distance metric, such as Euclidean distance or Manhattan distance.
#
# 3. Compute the reachability distance of each data point, which measures the local density of the point relative to its neighbors. The reachability distance of a point x with respect to a neighboring point y is defined as the maximum distance between x and y, or the distance between x and its k-th nearest neighbor, whichever is larger.
#
# 4. Compute the local reachability density of each data point, which measures the average reachability distance of the point's neighbors. The local reachability density of a point x is defined as the inverse of the average reachability distance of x's k-nearest neighbors.
#
# 5. Compute the LOF score of each data point, which measures the degree to which the point is an outlier relative to its local neighborhood. The LOF score of a point x is defined as the ratio of the average local reachability density of x's k-nearest neighbors to x's own local reachability density. A point with an LOF score significantly less than 1 is considered a potential local outlier.
#
# 6. Set a threshold for the LOF score, above which a data point is considered a local outlier. The threshold can be set based on the characteristics of the dataset and the desired level of sensitivity to local outliers.
#
# ### In summary, the LOF algorithm computes a score for each data point based on its local density relative to its k-nearest neighbors. Data points with a significantly lower density than their neighbors are considered potential local outliers, and their LOF scores can be used to rank them according to their degree of outlierness. By adjusting the parameters of the algorithm, such as the value of k and the LOF score threshold, it is possible to control the sensitivity of the algorithm to local outliers.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Question 10</p>

# %% [markdown]
# ## Question 10: How can global outliers be detected using the Isolation Forest algorithm?
# ---

# %% [markdown]
# ## Answer :

# %% [markdown]
# ### The Isolation Forest algorithm is a popular tree-based technique for detecting global outliers in a dataset. The Isolation Forest algorithm works by constructing isolation trees on the dataset, which are binary trees that partition the data into subsets based on random thresholds of the features. Global outliers are then identified as data points that are isolated or separated from the rest of the data in the fewest number of steps.
#
# ### Here are the main steps involved in using the Isolation Forest algorithm to detect global outliers:
#
# 1. Determine the number of isolation trees to be constructed. This parameter can be set based on the characteristics of the dataset and the desired level of sensitivity to global outliers.
#
# 2. Randomly select a subset of the data and construct an isolation tree on the subset. This is done recursively by randomly selecting a feature and a threshold value to split the data into two subsets, and continuing the process until each subset contains a single data point or a predetermined maximum depth is reached.
#
# 3. Repeat step 2 for the specified number of isolation trees. This results in a forest of isolation trees that partition the data into subsets based on random thresholds of the features.
#
# 4. Compute the isolation score of each data point, which measures the number of steps required to isolate the point from the rest of the data in the isolation trees. The isolation score of a point x is defined as the average path length of x in the isolation trees, normalized by the maximum path length.
#
# 5. Set a threshold for the isolation score, below which a data point is considered a global outlier. The threshold can be set based on the characteristics of the dataset and the desired level of sensitivity to global outliers.
#
# ### In summary, the Isolation Forest algorithm constructs isolation trees on the dataset, which are binary trees that partition the data into subsets based on random thresholds of the features. Global outliers are then identified as data points that are isolated or separated from the rest of the data in the fewest number of steps. By adjusting the parameters of the algorithm, such as the number of isolation trees and the isolation score threshold, it is possible to control the sensitivity of the algorithm to global outliers.
#
# ### Below is python code to detect global outliers :

# %%
from sklearn.ensemble import IsolationForest
import numpy as np
import matplotlib.pyplot as plt

# Generate some sample data
rng = np.random.RandomState(42)
X = 0.3 * rng.randn(100, 2)
X_outliers = rng.uniform(low=-4, high=4, size=(20, 2))
X = np.concatenate([X, X_outliers], axis=0)

# Fit the Isolation Forest model
clf = IsolationForest(n_estimators=100, contamination=0.1, random_state=rng)
clf.fit(X)

# Predict the outliers
y_pred = clf.predict(X)

# Plot the data points with different colors for normal points and outliers
plt.scatter(X[:, 0], X[:, 1], c=y_pred, cmap='cool')
plt.title("Isolation Forest - Detected Outliers")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %% [markdown]
# ### In this example, we first generate a synthetic dataset with 100 normal data points and 20 global outliers. We then create an instance of the IsolationForest class with 100 trees and a contamination rate of 0.1 (i.e., we expect 10% of the data to be global outliers). We fit the model on the data and use the predict method to obtain the predicted labels for each data point, where -1 indicates a global outlier and 1 indicates a normal data point. Finally, we use Matplotlib to visualize the data points with different colors for normal points and outliers.

# %% [markdown]
# ## Question 11 : What are some real-world applications where local outlier detection is more appropriate than global outlier detection, and vice versa?
# ---

# %% [markdown]
# ### Both local and global outlier detection techniques have their unique advantages and disadvantages, and their suitability depends on the specific characteristics of the data and the application domain. Here are some examples of real-world applications where local outlier detection may be more appropriate than global outlier detection, and vice versa:
#
# ### Local Outlier Detection:
#
# 1. `Network intrusion detection`: In network intrusion detection, local outlier detection can be used to detect unusual patterns in network traffic, such as an individual node sending or receiving an unusually high amount of data, which could indicate a potential security breach.
#
# 2. `Fraud detection`: In financial fraud detection, local outlier detection can be used to identify anomalous transactions by comparing them to the historical behavior of the same user or group of users. For example, a sudden large transaction made by an individual who typically only makes small transactions may be considered a local outlier.
#
# ### Global Outlier Detection:
#
# 1. `Manufacturing quality control`: In manufacturing, global outlier detection can be used to identify defective products that differ significantly from the expected quality standard. For example, a batch of products that are all below a certain weight threshold could be flagged as global outliers.
#
# 2. `Environmental monitoring`: In environmental monitoring, global outlier detection can be used to identify unusual events or changes in the overall patterns of data collected over a large area or time period. For example, a sudden spike in air pollution levels across an entire city could be considered a global outlier.
#
# ### Overall, the choice of local or global outlier detection techniques depends on the nature of the data and the specific requirements of the application. It is important to carefully evaluate the pros and cons of each approach before deciding which technique to use.
